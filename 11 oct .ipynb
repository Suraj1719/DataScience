# %%
import pandas as pd 
import numpy as np

# %%
data = pd.read_csv('32_Murder_victim_age_sex.csv')
data.dtypes
# Out:
# Area_Name                  object
# Year                        int64
# Group_Name                 object
# Sub_Group_Name             object
# Victims_Above_50_Yrs      float64
# Victims_Total               int64
# Victims_Upto_10_15_Yrs    float64
# Victims_Upto_10_Yrs       float64
# Victims_Upto_15_18_Yrs    float64
# Victims_Upto_18_30_Yrs    float64
# Victims_Upto_30_50_Yrs    float64
# dtype: object

# %%
data.shape
# Out:
# (1018, 11)

# %%
data.sample(5)
# Out:
#        Area_Name  Year               Group_Name     Sub_Group_Name  \
# 88       Mizoram  2003  Murder - Female Victims  2. Female Victims
# 539  West Bengal  2006    Murder - Male Victims    1. Male Victims
# 611        Assam  2009    Murder - Male Victims    1. Male Victims
# 65   West Bengal  2002  Murder - Female Victims  2. Female Victims
# 510        Bihar  2006    Murder - Male Victims    1. Male Victims
#
#      Victims_Above_50_Yrs  Victims_Total  Victims_Upto_10_15_Yrs  \
# 88                    NaN              9                     NaN
# 539                  52.0            995                     0.0
# 611                  40.0           1226                     0.0
# 65                    9.0            272                     0.0
# 510                 103.0           2836                     1.0
#
#      Victims_Upto_10_Yrs  Victims_Upto_15_18_Yrs  Victims_Upto_18_30_Yrs  \
# 88                   NaN                     NaN                     5.0
# ...

# %%
# null data

data.isnull().sum()
# Out:
# Area_Name                   0
# Year                        0
# Group_Name                  0
# Sub_Group_Name              0
# Victims_Above_50_Yrs       56
# Victims_Total               0
# Victims_Upto_10_15_Yrs    142
# Victims_Upto_10_Yrs       118
# Victims_Upto_15_18_Yrs    130
# Victims_Upto_18_30_Yrs      9
# Victims_Upto_30_50_Yrs     11
# dtype: int64

# %%
# year 
data.Year.unique()
# Out:
# array([2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010])

# %%
mih = data.groupby(["Year",'Group_Name']).sum()
mih
# Out:
#                               Victims_Above_50_Yrs  Victims_Total  \
# Year Group_Name
# 2001 Murder - Female Victims                 667.0           8370
#      Murder - Male Victims                  2794.0          30266
#      Murder - Total Victims                 3461.0          38636
# 2002 Murder - Female Victims                 675.0           8196
#      Murder - Male Victims                  2624.0          29837
#      Murder - Total Victims                 3299.0          38033
# 2003 Murder - Female Victims                 650.0           7505
#      Murder - Male Victims                  2362.0          26316
#      Murder - Total Victims                 3012.0          33821
# 2004 Murder - Female Victims                 664.0           8119
#      Murder - Male Victims                  2485.0          26796
#      Murder - Total Victims                 3149.0          34915
# 2005 Murder - Female Victims                 644.0           7952
# ...

# %%
data['Victims_Total'].sum()
# Out:
# 695708

# %%
mih.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 342 entries, (2001, 'Andaman & Nicobar Islands') to (2010, 'West Bengal')
# Data columns (total 7 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Victims_Above_50_Yrs    342 non-null    float64
#  1   Victims_Total           342 non-null    int64
#  2   Victims_Upto_10_15_Yrs  342 non-null    float64
#  3   Victims_Upto_10_Yrs     342 non-null    float64
#  4   Victims_Upto_15_18_Yrs  342 non-null    float64
#  5   Victims_Upto_18_30_Yrs  342 non-null    float64
#  6   Victims_Upto_30_50_Yrs  342 non-null    float64
# dtypes: float64(6), int64(1)
# memory usage: 19.8+ KB

# %%
data['Area_Name'].nunique() * data['Year'].nunique() - mih.shape[0]
# Out:
# 8

# %%
import matplotlib.pyplot as plt
mih.loc[2003:2005].plot(kind='bar', figsize = (20, 8))
# Out:
# <AxesSubplot:xlabel='Year,Group_Name'>

# %%
data
# Out:
#                       Area_Name  Year               Group_Name  \
# 0     Andaman & Nicobar Islands  2001  Murder - Female Victims
# 1                Andhra Pradesh  2001  Murder - Female Victims
# 2             Arunachal Pradesh  2001  Murder - Female Victims
# 3                         Assam  2001  Murder - Female Victims
# 4                         Bihar  2001  Murder - Female Victims
# ...                         ...   ...                      ...
# 1013                 Tamil Nadu  2010   Murder - Total Victims
# 1014                    Tripura  2010   Murder - Total Victims
# 1015              Uttar Pradesh  2010   Murder - Total Victims
# 1016                Uttarakhand  2010   Murder - Total Victims
# 1017                West Bengal  2010   Murder - Total Victims
#
#          Sub_Group_Name  Victims_Above_50_Yrs  Victims_Total  \
# 0     2. Female Victims                   NaN              6
# 1     2. Female Victims                  67.0            607
# ...

# %%
data.fillna(value=0, inplace=True)

# %%
data_15_30 = data[['Area_Name','Group_Name','Victims_Upto_15_18_Yrs','Victims_Upto_18_30_Yrs']]
data_15_30['victims_15_30'] = data_15_30['Victims_Upto_15_18_Yrs'] + data_15_30['Victims_Upto_18_30_Yrs']
data_15_30.drop(['Victims_Upto_15_18_Yrs','Victims_Upto_18_30_Yrs'], axis=1, inplace=True)
data_15_30
# Out:
# <ipython-input-82-a355a395d029>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_15_30['victims_15_30'] = data_15_30['Victims_Upto_15_18_Yrs'] + data_15_30['Victims_Upto_18_30_Yrs']
# /Users/sumitkumarshukla/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
#                       Area_Name               Group_Name  victims_15_30
# 0     Andaman & Nicobar Islands  Murder - Female Victims            4.0
# ...

# %%
data['Sub_Group_Name'].value_counts()
# Out:
# 3. Total             342
# 1. Male Victims      339
# 2. Female Victims    337
# Name: Sub_Group_Name, dtype: int64

# %%
data[['Group_Name','Year']].value_counts()
# Out:
# Group_Name               Year
# Murder - Total Victims   2008    35
#                          2005    35
# Murder - Female Victims  2008    35
# Murder - Male Victims    2006    34
#                          2007    34
# Murder - Total Victims   2009    34
#                          2007    34
#                          2006    34
#                          2004    34
#                          2003    34
#                          2002    34
#                          2001    34
# Murder - Male Victims    2010    34
#                          2009    34
#                          2008    34
# Murder - Total Victims   2010    34
# Murder - Male Victims    2005    34
#                          2004    34
#                          2003    34
#                          2002    34
# Murder - Female Victims  2009    34
#                          2007    34
#                          2006    34
#                          2004    34
#                          2003    34
# ...

# %%
data_15_30['Year'] = data['Year']
data_15_30[data_15_30['Area_Name']=='Assam']
# Out:
# <ipython-input-103-18f6c8660e2c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_15_30['Year'] = data['Year']
#     Area_Name               Group_Name  victims_15_30  Year
# 3       Assam  Murder - Female Victims           68.0  2001
# 36      Assam  Murder - Female Victims           64.0  2002
# 69      Assam  Murder - Female Victims           68.0  2003
# 103     Assam  Murder - Female Victims           55.0  2004
# 137     Assam  Murder - Female Victims           42.0  2005
# 170     Assam  Murder - Female Victims           43.0  2006
# 204     Assam  Murder - Female Victims           51.0  2007
# 238     Assam  Murder - Female Victims           61.0  2008
# 273     Assam  Murder - Female Victims           62.0  2009
# ...

# %%
68 + 746
# Out:
# 814

# %%
773 - 722
# Out:
# 51
