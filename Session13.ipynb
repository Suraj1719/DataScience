# %%
import numpy as np
import pandas as pd

# %%
from seaborn import load_dataset,get_dataset_names
get_dataset_names()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10136/1700661703.py in <module>
# ----> 1 from seaborn import load_dataset,get_dataset_names
#       2 get_dataset_names()
#
# ModuleNotFoundError: No module named 'seaborn'

# %%
from seaborn import load_dataset,get_dataset_names
get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'exercise',
#  'flights',
#  'fmri',
#  'gammas',
#  'geyser',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'taxis',
#  'tips',
#  'titanic']

# %%
dn = get_dataset_names()
len(dn)
# Out:
# 19

# %%
def datasets():
    for dataset in dn :
        x=load_dataset(str(dataset))
        print(x.info())
        print('\n\n')

# %%
datasets()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   subidr  20 non-null     int64
#  1   attnr   20 non-null     object
#  2   num1    20 non-null     int64
#  3   num2    20 non-null     float64
#  4   num3    20 non-null     int64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 928.0+ bytes
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44 entries, 0 to 43
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   dataset  44 non-null     object
#  1   x        44 non-null     float64
#  2   y        44 non-null     float64
# dtypes: float64(2), object(1)
# memory usage: 1.2+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60 entries, 0 to 59
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ...

# %%
data=load_dataset('titanic')
data.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
#if you want to know the value of mal and female passenger
data['sex'].value_counts()
# Out:
# male      577
# female    314
# Name: sex, dtype: int64

# %%
data['sex'].value_counts(),data.shape[0]
# Out:
# (male      577
#  female    314
#  Name: sex, dtype: int64,
#  891)

# %%
#if you want the ratio
data['sex'].value_counts()/data.shape[0]
# Out:
# male      0.647587
# female    0.352413
# Name: sex, dtype: float64

# %%
#if you want percentage of value
data['sex'].value_counts()/data.shape[0]*100
# Out:
# male      64.758698
# female    35.241302
# Name: sex, dtype: float64

# %%
#if you want to check the survived male
data[(data['survived']==1) & (data['sex']=='male')]
# Out:
#      survived  pclass   sex   age  sibsp  parch     fare embarked   class  \
# 17          1       2  male   NaN      0      0  13.0000        S  Second
# 21          1       2  male  34.0      0      0  13.0000        S  Second
# 23          1       1  male  28.0      0      0  35.5000        S   First
# 36          1       3  male   NaN      0      0   7.2292        C   Third
# 55          1       1  male   NaN      0      0  35.5000        S   First
# ..        ...     ...   ...   ...    ...    ...      ...      ...     ...
# 838         1       3  male  32.0      0      0  56.4958        S   Third
# 839         1       1  male   NaN      0      0  29.7000        C   First
# 857         1       1  male  51.0      0      0  26.5500        S   First
# 869         1       3  male   4.0      1      1  11.1333        S   Third
# 889         1       1  male  26.0      0      0  30.0000        C   First
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
#if you want the female members allive
data[(data['survived']==1) & (data['sex']=='female')]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 8           1       3  female  27.0      0      2  11.1333        S   Third
# 9           1       2  female  14.0      1      0  30.0708        C  Second
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 874         1       2  female  28.0      1      0  24.0000        C  Second
# 875         1       3  female  15.0      0      0   7.2250        C   Third
# 879         1       1  female  56.0      0      1  83.1583        C   First
# 880         1       2  female  25.0      0      1  26.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
#percentage of survival of male over total male passenger
data[(data['survived']==1) & (data['sex']=='male')].shape[0]/data[data['sex']=='male'].shape[0]*100
# Out:
# 18.890814558058924

# %%
#percentage of survival of female over total female passenger
data[(data['survived']==1) & (data['sex']=='female')].shape[0]/data[data['sex']=='female'].shape[0]*100
# Out:
# 74.20382165605095
